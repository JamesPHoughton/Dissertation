# %%
# %pylab inline
import networkx as nx

import sys
import os
path = os.getcwd() + '/../Shared'
sys.path.append(path)
from threshold_model import ThresholdModel
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
num_nodes = 25
num_cliques = 3
g = nx.connected_watts_strogatz_graph(num_nodes, 6, .01, 20)
thresholds = [2]*num_nodes

# %%
model = ThresholdModel(g, numerical_threshold=thresholds)
model.draw()

# %%
from IPython.display import HTML
model.run()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/houghton/anaconda/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     341             method = _safe_get_formatter_method(obj, self.print_method)
#     342             if method is not None:
# --> 343                 return method()
#     344             return None
#     345         else:
#
# /Users/houghton/anaconda/lib/python2.7/site-packages/matplotlib/animation.pyc in _repr_html_(self)
#     979         fmt = rcParams['animation.html']
#     980         if fmt == 'html5':
# --> 981             return self.to_html5_video()
#     982
#     983
#
# /Users/houghton/anaconda/lib/python2.7/site-packages/matplotlib/animation.pyc in to_html5_video(self)
#     949                 # We create a writer manually so that we can get the
#     950                 # appropriate size for the tag
# ...

# %%
model.seed([1,2])
model.draw()

# %%
model.step()
model.draw()

# %%
model.step()
model.draw()

# %%
from yapf.yapf_api import FormatCode
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-2ba4c385f4ee> in <module>()
# ----> 1 from yapf.yapf_api import FormatCode
#
# ImportError: No module named yapf_api

# %%
import yapf

# %%
yapf.yapf_api.FormatCode()
# Out:
# <function yapf.yapflib.yapf_api.FormatCode>
