# %%
# %pylab inline
import pysd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# !cat ../Survey_of_Social_Movement_Models/Tsebelis_Sprague_1989/Tsebelis_Sprague_1989.mdl
# Out:
# {UTF-8}
# Coercive Influence on Revolution g  = A FUNCTION OF( )
# 	~
# 	~		|
#
# Coersion C  = A FUNCTION OF( -Decrease in Coersion,Increase in Coersion)
# 	~
# 	~		|
#
# Decrease in Coersion=
# 	Natural Decrease in Coersion
# 	~
# 	~		|
#
# Decrease in Foreign Intervention  = A FUNCTION OF( Decrease in Foreign Intervention due to Coersion\
# 		,Natural Decrease in Foreign Intervention)
# 	~
# 	~		|
#
# Decrease in Foreign Intervention due to Coersion  = A FUNCTION OF( Coersion C,Influence of Coersion on Foreign Intervention\
# 		)
# 	~
# 	~		|
#
# Decrease in Relative Deprivation=
# 	Natural Decrease in Relative Deprivation + Psychological Release of Deprivation
# 	~
# 	~		|
#
# Decrease in Revolution  = A FUNCTION OF( Decrease in Revolution due to Coersion,Natural Decrease in Revolution\
# 		) ~~|
# Decrease in Revolution=
# 	Natural Decrease in Revolution
# 	~
# 	~		|
#
# Decrease in Revolution due to Coersion=
# 	Coercive Influence on Revolution g * Coersion C
# 	~
# 	~		|
#
# ...

# %%
model = pysd.read_vensim('../Survey_of_Social_Movement_Models/Tsebelis_Sprague_1989/Tsebelis_Sprague_1989.mdl')
model.run()
# Out:
# ---------------------------------------------------------------------------
# ParseError                                Traceback (most recent call last)
# <ipython-input-2-8736ef45242b> in <module>()
# ----> 1 model = pysd.read_vensim('../Survey_of_Social_Movement_Models/Tsebelis_Sprague_1989/Tsebelis_Sprague_1989.mdl')
#       2 model.run()
#
# /Users/houghton/anaconda/lib/python2.7/site-packages/pysd/pysd.pyc in read_vensim(mdl_file)
#      61     """
#      62     from translators import translate_vensim
# ---> 63     py_model_file = translate_vensim(mdl_file)
#      64     model = load(py_model_file)
#      65     model.__str__ = 'Import of ' + mdl_file
#
# /Users/houghton/anaconda/lib/python2.7/site-packages/pysd/translators/vensim2py.pyc in translate_vensim(mdl_file)
#     598     # Step 2 parser writes the file
#     599     outfile_name = mdl_file[:-4]+'.py'
# --> 600     parser = TextParser(file_grammar, outfile_name, text, dictofsubs)
#     601     parser.builder.write()
# ...
