# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
http://www.clinecenter.illinois.edu/data/speed/event/

# %%
protests = pd.read_csv('ssp_public.csv')
protests.head()
# Out:
#    cowcode  month  year    eventid country INI_IGRP1 TAR_IGRP1 VIC_IGRP1  \
# 0      NaN    NaN  1946   EID40124     NaN         .         .         .
# 1      NaN    NaN  1946   EID51193     NaN         .         .         .
# 2      NaN     11  1948  EID133296     NaN         .         .         .
# 3      NaN      9  1951  EID102797     NaN         .         .         .
# 4      NaN      7  1952  EID257135     NaN         .         .         .
#
#   INI_SGRP1 TAR_SGRP1       ...       PERS_SECURITY QUASI_EVENT coup  \
# 0         .         .       ...                   0           0    0
# 1         .         .       ...                   0           0    0
# 2         .         .       ...                   0           0    0
# 3         .         .       ...                   0           0    0
# 4         .         .       ...                   0           0    0
#
#   COUP_FAILED  region  ctry_bias  victim_effect  weapon  property_damaged  \
# ...
